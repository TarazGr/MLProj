# %%
# %matplotlib inline

import pandas as pd
import numpy as np

# %%
LastFM = pd.read_csv("lastFM_Scraping.csv", sep=',', encoding="utf-8", index_col=False, header=0, names=["track", "artist", "listeners", "plays", "duration", "genre"])
Spotify = pd.read_csv("spotify_Scraping.csv", sep=',', encoding="utf-8", index_col=False, header=0, names=["artist", "genres", "followers", "popularity"])
Billboard = pd.read_csv("billboard.csv", sep=',', encoding="utf-8", index_col=False, header=0, names=["track", "artist", "peak", "rank"])

# %%
LastFM["duration"] = LastFM["duration"]/1000
LastFM
# Out:
#                           track                                 artist  \
# 0                 4th Dimension  KIDS SEE GHOSTS Featuring Louis Prima
# 1        All Girls Are The Same                             Juice WRLD
# 2                      All Mine                             Kanye West
# 3                          Babe       Sugarland Featuring Taylor Swift
# 4                   Back To You                           Selena Gomez
# 5                   Ball For Me      Post Malone Featuring Nicki Minaj
# 6                    Be Careful                                Cardi B
# 7               Beautiful Crazy                             Luke Combs
# 8                    Better Now                            Post Malone
# 9                      Boo'd Up                               Ella Mai
# 10             Call Out My Name                             The Weeknd
# 11                      Chun-Li                            Nicki Minaj
# ...

# %%
Spotify["popularity"] = Spotify["popularity"]/100
Spotify
# Out:
#                         artist  \
# 0                   Juice WRLD
# 1                   Kanye West
# 2                 Selena Gomez
# 3                      Cardi B
# 4                   Luke Combs
# 5                  Post Malone
# 6                     Ella Mai
# 7                   The Weeknd
# 8                  Nicki Minaj
# 9              KIDS SEE GHOSTS
# 10                Taylor Swift
# 11                Daddy Yankee
# 12                    Lil Pump
# 13                         BTS
# 14               Kenny Chesney
# 15                       Drake
# 16                  Kane Brown
# 17                        Lauv
# 18               Blake Shelton
# 19                   Jake Owen
# 20                    Dua Lipa
# 21                Shawn Mendes
# 22                  Famous Dex
# 23                     J. Cole
# 24                 Brett Young
# 25                       Bazzi
# 26              Camila Cabello
# 27               Ariana Grande
# 28  YoungBoy Never Broke Again
# ...

# %%
Billboard.head()
# Out:
#                     track                                    artist  peak  \
# 0           4th Dimension     KIDS SEE GHOSTS Featuring Louis Prima    42
# 1  All Girls Are The Same                                Juice WRLD    41
# 2                All Mine                                Kanye West    11
# 3                   Alone  Halsey Featuring Big Sean & Stefflon Don    70
# 4                    Babe          Sugarland Featuring Taylor Swift    72
#
#    rank
# 0    42
# 1    41
# 2    31
# 3    74
# 4    95
